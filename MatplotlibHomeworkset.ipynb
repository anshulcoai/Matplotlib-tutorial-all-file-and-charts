# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\pc\Downloads\salesman.csv',parse_dates=['Date'])
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_4844\303024264.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df=pd.read_csv(r'C:\Users\pc\Downloads\salesman.csv',parse_dates=['Date'])

# %%
df
# Out:
#            Date Salesman  Revenue
# 0    2016-01-01      Bob     7172
# 1    2016-01-02      Bob     6362
# 2    2016-01-03      Bob     5982
# 3    2016-01-04      Bob     7917
# 4    2016-01-05      Bob     7837
# ...         ...      ...      ...
# 1825 2016-12-27    Oscar      835
# 1826 2016-12-28    Oscar     3073
# 1827 2016-12-29    Oscar     6424
# 1828 2016-12-30    Oscar     7088
# 1829 2016-12-31    Oscar     8408
#
# [1830 rows x 3 columns]

# %%
df.head(50)
# Out:
#          Date Salesman  Revenue
# 0  2016-01-01      Bob     7172
# 1  2016-01-02      Bob     6362
# 2  2016-01-03      Bob     5982
# 3  2016-01-04      Bob     7917
# 4  2016-01-05      Bob     7837
# 5  2016-01-06      Bob     1744
# 6  2016-01-07      Bob      918
# 7  2016-01-08      Bob     9863
# 8  2016-01-09      Bob     8337
# 9  2016-01-10      Bob     7543
# 10 2016-01-11      Bob     1053
# 11 2016-01-12      Bob     4362
# 12 2016-01-13      Bob     6812
# 13 2016-01-14      Bob     9047
# 14 2016-01-15      Bob     3594
# 15 2016-01-16      Bob     9800
# 16 2016-01-17      Bob     7215
# 17 2016-01-18      Bob     7744
# 18 2016-01-19      Bob     9560
# 19 2016-01-20      Bob     9863
# 20 2016-01-21      Bob      547
# 21 2016-01-22      Bob     3505
# 22 2016-01-23      Bob     6969
# 23 2016-01-24      Bob      696
# 24 2016-01-25      Bob     4302
# 25 2016-01-26      Bob     9427
# 26 2016-01-27      Bob     7990
# 27 2016-01-28      Bob     6271
# ...

# %%
df.tail(50)
# Out:
#            Date Salesman  Revenue
# 1780 2016-11-12    Oscar     3196
# 1781 2016-11-13    Oscar     4632
# 1782 2016-11-14    Oscar     3546
# 1783 2016-11-15    Oscar     3655
# 1784 2016-11-16    Oscar      832
# 1785 2016-11-17    Oscar     3183
# 1786 2016-11-18    Oscar     1183
# 1787 2016-11-19    Oscar     3447
# 1788 2016-11-20    Oscar      509
# 1789 2016-11-21    Oscar     3143
# 1790 2016-11-22    Oscar     5637
# 1791 2016-11-23    Oscar     8001
# 1792 2016-11-24    Oscar     5578
# 1793 2016-11-25    Oscar     3460
# 1794 2016-11-26    Oscar     3292
# 1795 2016-11-27    Oscar     9674
# 1796 2016-11-28    Oscar      643
# 1797 2016-11-29    Oscar     1928
# 1798 2016-11-30    Oscar     4943
# 1799 2016-12-01    Oscar     6380
# 1800 2016-12-02    Oscar     5589
# 1801 2016-12-03    Oscar     6009
# 1802 2016-12-04    Oscar      537
# 1803 2016-12-05    Oscar     3895
# 1804 2016-12-06    Oscar     3060
# 1805 2016-12-07    Oscar      295
# ...

# %%
sales_data = df.groupby("Salesman")["Revenue"].sum()

plt.pie(sales_data, labels=sales_data.index, autopct='%1.1f%%')
plt.title("Sales Revenue Distribution by Salesman")
plt.show()

# %%
food=pd.read_csv(r'C:\Users\pc\Downloads\foods.csv')

# %%
food
# Out:
#     First Name  Gender          City Frequency       Item  Spend
# 0        Wanda  Female      Stamford    Weekly     Burger  15.66
# 1         Eric    Male      Stamford     Daily    Chalupa  10.56
# 2      Charles    Male      New York     Never      Sushi  42.14
# 3         Anna  Female  Philadelphia      Once  Ice Cream  11.01
# 4      Deborah  Female  Philadelphia     Daily    Chalupa  23.49
# ..         ...     ...           ...       ...        ...    ...
# 995      Donna  Female      New York   Monthly      Sushi  83.53
# 996     Albert    Male  Philadelphia     Daily      Sushi  72.88
# 997       Jean  Female      Stamford    Weekly      Donut   5.85
# 998    Jessica  Female      New York     Daily    Chalupa  43.19
# 999      Brian    Male      New York     Daily    Chalupa  28.36
#
# [1000 rows x 6 columns]

# %%
food['Item'].value_counts()
# Out:
# Item
# Donut        187
# Ice Cream    176
# Burrito      168
# Sushi        166
# Burger       156
# Chalupa      147
# Name: count, dtype: int64

# %%
avg_spent=food.groupby('Item')["Spend"].mean()

# %%
plt.figure(figsize=(10, 5))
plt.bar(avg_spent.index, avg_spent, color="teal")
plt.xlabel("Food Items")
plt.ylabel("Average Amount Spent")
plt.title("Average Spending on Each Food Item")

plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.pie(avg_spent, labels=avg_spent.index, autopct='%1.1f%%', startangle=140)
plt.title("Item-wise Average Spending")
plt.legend()
plt.show()

# %%
movie=pd.read_csv(r'C:\Users\pc\Downloads\movies.csv')

# %%
movie
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
total_salary = movie.groupby("Actor")["Bond Actor Salary"].sum()

# %%
total_salary
# Out:
# Actor
# Daniel Craig      25.9
# David Niven        0.0
# George Lazenby     0.6
# Pierce Brosnan    46.5
# Roger Moore       16.9
# Sean Connery      20.3
# Timothy Dalton    13.1
# Name: Bond Actor Salary, dtype: float64

# %%
plt.figure(figsize=(10, 5))
plt.bar(total_salary.index, total_salary, color="purple")
plt.xlabel("Bond Actors")
plt.ylabel("Total Salary Earned")
plt.title("Total Salary of Bond Actors")
plt.xticks(rotation=45)
plt.show()

# %%
fortune=pd.read_csv(r'C:\Users\pc\Downloads\fortune1000.csv')

# %%
fortune
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...
