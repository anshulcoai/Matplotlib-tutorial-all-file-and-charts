# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
iris=sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df=iris[iris['species']=='setosa']
sns.kdeplot(df['sepal_length'],label='setosa',color='g',shade=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_1636\335798058.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['sepal_length'],label='setosa',color='g',shade=True)
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
df_setosa=iris[iris['species']=='setosa']
sns.kdeplot(df['sepal_length'],label='setosa',color='g',shade=True)

df=iris[iris['species']=='virginica']
sns.kdeplot(df['sepal_length'],label='virginica',color='red',shade=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_1636\3837687717.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['sepal_length'],label='setosa',color='g',shade=True)
# C:\Users\pc\AppData\Local\Temp\ipykernel_1636\3837687717.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['sepal_length'],label='virginica',color='red',shade=True)
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
data=np.random.randint(low=1,high=100,size=(10,10))
sns.heatmap(data=data)
# Out:
# <Axes: >

# %%
data
# Out:
# array([[78, 16, 32, 24, 77, 88, 31, 25,  4, 11],
#        [94, 13, 23, 71, 27, 55, 23, 36, 18, 25],
#        [81, 31, 37, 24,  8, 83, 76, 33, 39,  5],
#        [56, 89, 72, 12, 79, 61,  5,  1, 34, 56],
#        [70, 51, 81, 59, 95, 27,  4, 26, 87, 98],
#        [34, 27, 33, 33, 75, 98, 64, 32, 17, 50],
#        [ 2, 68, 97, 61, 76, 95, 15, 56, 62, 84],
#        [41, 14, 12, 76, 18, 18, 77, 66, 60,  4],
#        [60, 30, 90, 97, 22, 10, 31, 98, 68, 22],
#        [69,  2, 88, 57, 64, 36,  1, 39, 33, 14]], dtype=int32)

# %%
data=np.random.randint(low=1,high=100,size=(10,10))
sns.heatmap(data=data,annot=True)
# Out:
# <Axes: >

# %%
titanic=sns.load_dataset('titanic')
group=titanic.groupby(['pclass', 'survived'])
pclass_survived=group.size().unstack()
sns.heatmap(pclass_survived,annot=True,fmt='d')
# Out:
# <Axes: xlabel='survived', ylabel='pclass'>

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...
