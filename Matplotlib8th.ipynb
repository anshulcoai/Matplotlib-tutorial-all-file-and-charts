# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris=sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.lineplot(x='sepal_length',y='sepal_width',data=iris)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
iris=sns.load_dataset('iris')
sns.lineplot(x='sepal_length',y='sepal_width',data=iris)
plt.title('Representation of Sepal Length to sepal width')
# Out:
# Text(0.5, 1.0, 'Representation of Sepal Length to sepal width')

# %%
iris=sns.load_dataset('iris')
sns.lineplot(x='sepal_length',y='sepal_width',data=iris)
sns.set_style('darkgrid')
plt.title('Representation of Sepal Length to sepal width')
plt.xlim(5)
# Out:
# (5.0, 8.08)

# %%
iris=sns.load_dataset('iris')
sns.lineplot(x='sepal_length',y='sepal_width',data=iris)
sns.despine()
plt.title('Representation of Sepal Length to sepal width')
plt.xlim(5)
# Out:
# (5.0, 8.08)

# %%
iris=sns.load_dataset('iris')
plt.subplot(211)
sns.lineplot(x='sepal_length',y='sepal_width',data=iris)
plt.title('Representation of Sepal Length to sepal width')

plt.subplot(212)
sns.lineplot(x='petal_length',y='petal_width',data=iris)
plt.title('Representation of Sepal Length to sepal width')

plt.xlim(5)
# Out:
# (5.0, 7.195)

# %%
iris=sns.load_dataset('iris')
fig=plt.figure(figsize=(7,5))
ax1=fig.add_axes([0.1,0.1,0.8,0.8])
sns.lineplot(x='sepal_length',y='sepal_width',data=iris)

ax2=fig.add_axes([0.5,0.5,0.3,0.3])
sns.lineplot(x='petal_length',y='petal_width',data=iris)
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
iris=sns.load_dataset('iris')
plt.subplot(121)
sns.lineplot(x='sepal_length',y='sepal_width',data=iris)

plt.subplot(122)
sns.lineplot(x='petal_length',y='petal_width',data=iris)
plt.title('Representation of Sepal Length to sepal width')

plt.xlim(5)
# Out:
# (5.0, 7.195)

# %%
iris=sns.load_dataset('iris')
sns.scatterplot(x='sepal_length',y='sepal_width',data=iris)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
fmri=sns.load_dataset('fmri')

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.scatterplot(x='timepoint',y='signal',data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.scatterplot(x='timepoint',y='signal',data=fmri,hue='region')
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.scatterplot(x='timepoint',y='signal',data=fmri,hue='region',marker='+')
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
tip=sns.load_dataset('tips')

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x='day',y='tip',data=tip,hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.scatterplot(x='day',y='tip',data=tip,hue='time')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.scatterplot(x='day',y='tip',data=tip,hue='time',style='time')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.scatterplot(x='day',y='tip',data=tip,hue='time',style='time',palette='pastel')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.scatterplot(x='day',y='tip',data=tip,hue='size',size='size')
# Out:
# <Axes: xlabel='day', ylabel='tip'>
