# %%
import seaborn as sns
import pandas as pd

# %%
fmri=sns.load_dataset('fmri')

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.boxplot(x='timepoint',y='signal',data=fmri,color='red')
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
tip=sns.load_dataset('tips')

# %%
sns.boxplot(x='day',y='tip',data=tip)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.boxplot(x='day',y='tip',hue='sex',data=tip)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
tip.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tip.boxplot(by='day',column=['total_bill'])
# Out:
# <Axes: title={'center': 'total_bill'}, xlabel='day'>

# %%
tip.boxplot(by='day',column=['total_bill'],grid=False)
# Out:
# <Axes: title={'center': 'total_bill'}, xlabel='day'>

# %%
sns.violinplot(x='timepoint',y='signal',data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.violinplot(x='day',y='tip',data=tip)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.violinplot(x='day',y='tip',hue='smoker',data=tip)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.violinplot(x=tip['tip'],y=tip['sex'])
# Out:
# <Axes: xlabel='tip', ylabel='sex'>

# %%
sns.violinplot(x=tip['tip'],y=tip['sex'],hue=tip['smoker'])
# Out:
# <Axes: xlabel='tip', ylabel='sex'>

# %%
sns.set(style='whitegrid')
sns.stripplot(x='day',y='tip',data=tip)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.set(style='whitegrid')
sns.stripplot(x='day',y='tip',hue='sex',data=tip)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.set(style='whitegrid')
sns.stripplot(x='day',y='tip',hue='sex',data=tip,jitter=0.1)
# Out:
# <Axes: xlabel='day', ylabel='tip'>
