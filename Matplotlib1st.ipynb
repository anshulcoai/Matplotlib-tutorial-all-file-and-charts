# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt

# %%
d=[]
for i in range(1,5):
    d.append(random.randrange(10))
a=np.array(d)
a
b=a**2

# %%
a
# Out:
# array([6, 3, 2, 8])

# %%
b
# Out:
# array([36,  9,  4, 64])

# %%
plt.plot(a,b)
plt.title('Square of the given numbers')
# Out:
# Text(0.5, 1.0, 'Square of the given numbers')

# %%
x=[0,5,4,6,3,8,1,7,9]
y=[8,5,6,1,4,7,2,3,4]
fig=plt.figure()
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y)

# %%
fig=plt.figure()
ax=plt.axes([0.1,0.1,0.8,0.8])
